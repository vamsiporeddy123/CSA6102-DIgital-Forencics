# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsiporeddy123/CSA6102-DIgital-Forencics/blob/main/Exp_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a sample storage image
with open("storage.bin", "wb") as f:
    f.write(b"RANDOMDATA")
    f.write(b"%PDF-1.4 Deleted PDF File")
    f.write(b"XXXX")
    f.write(b"\x89PNG\r\n\x1a\n Deleted PNG File")
    f.write(b"YYYY")
    f.write(b"\xFF\xD8\xFF Deleted JPG File")

# File signatures (magic numbers)
signatures = {
    b"%PDF": "PDF Document",
    b"\x89PNG\r\n\x1A\n": "PNG Image",
    b"\xFF\xD8\xFF": "JPEG Image"
}

# Read storage image
with open("storage.bin", "rb") as file:
    data = file.read()

print("Scanning storage for deleted files...\n")

found = False

for signature, file_type in signatures.items():
    position = data.find(signature)
    if position != -1:
        print(file_type, "found at byte", position)
        found = True

if not found:
    print("No deleted files found.")
# Out:
# Scanning storage for deleted files...
#
# PDF Document found at byte 10
# PNG Image found at byte 39
# JPEG Image found at byte 68

# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsiporeddy123/CSA6102-DIgital-Forencics/blob/main/Exp_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import hashlib

original_path = "original_evidence.bin"

with open(original_path, "wb") as f:
    f.write(os.urandom(1024))

def bit_stream_copy(src_path, dst_path):
    with open(src_path, "rb") as src, open(dst_path, "wb") as dst:
        dst.write(src.read())


copy_path = "bitstream_copy.bin"
bit_stream_copy(original_path, copy_path)


def sha256_of_file(path):
    with open(path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

original_hash = sha256_of_file(original_path)
copy_hash = sha256_of_file(copy_path)

print("Original hash:", original_hash)
print("Copy hash:    ", copy_hash)


if original_hash == copy_hash:
    print("\nIntegrity Verified: The bit-stream copy is identical to the original.")
else:
    print("\nIntegrity Check Failed: The copy differs from the original.")
# Out:
# Original hash: 0a11aa1169b548af2f0f193d0293070951bd72622051955357eed4c4d120bf0b
# Copy hash:     0a11aa1169b548af2f0f193d0293070951bd72622051955357eed4c4d120bf0b
#
# Integrity Verified: The bit-stream copy is identical to the original.

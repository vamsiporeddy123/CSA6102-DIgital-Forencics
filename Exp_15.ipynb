# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsiporeddy123/CSA6102-DIgital-Forencics/blob/main/Exp_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import psutil

def capture_volatile_evidence():
    processes = [p.info for p in psutil.process_iter(['pid', 'name'])]
    return {
        "running_process_count": len(processes),
        "sample_processes": processes[:5],
    }

def capture_nonvolatile_evidence(folder):
    files = sorted(os.listdir(folder))
    return {
        "disk_files": files,
        "file_count": len(files)
    }

evidence_dir = "digital_evidence"

# Create the directory if it does not exist
os.makedirs(evidence_dir, exist_ok=True)

volatile_snapshot = capture_volatile_evidence()
nonvolatile_snapshot = capture_nonvolatile_evidence(evidence_dir)

print("Volatile evidence -> running processes:",
      volatile_snapshot["running_process_count"])

print("\nSample running processes:")
for process in volatile_snapshot["sample_processes"]:
    print(process)

print("\nNon-volatile evidence:")
print(nonvolatile_snapshot)
# Out:
# Volatile evidence -> running processes: 15
#
# Sample running processes:
# {'name': 'docker-init', 'pid': 1}
# {'name': 'node', 'pid': 7}
# {'name': 'oom_monitor.sh', 'pid': 15}
# {'name': 'run.sh', 'pid': 17}
# {'name': 'kernel_manager_proxy', 'pid': 18}
#
# Non-volatile evidence:
# {'disk_files': [], 'file_count': 0}
